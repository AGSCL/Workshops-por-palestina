# %% [markdown]
# # Instalando Tutoriales para usar R en Colab

# %% [markdown]
# ## Usar R

# %% [markdown]
# Cambiamos el entorno de ejecución desde Python a R
# ![captura0a.png](data:image/png;base64,...)

# %% [markdown]
# Elegimos R

# %% [markdown]
# ![captura0b.png](data:image/png;base64,...)

# %% [markdown]
# ## Instalando programas básicos

# %% [markdown]
# Instala estos paquetes si no se encuentran instalados: "devtools", "bitops", "RCurl", "stringi", "httr", "swirl"

# %%
if (!require("devtools")) install.packages("devtools")
if (!require("bitops")) install.packages("bitops")
if (!require("RCurl")) install.packages("RCurl")
if (!require("stringi")) install.packages("stringi")
if (!require("httr")) install.packages("httr")
if (!require("swirl")) install.packages("swirl")
# Out:
# Loading required package: devtools
#
# Loading required package: usethis
#
# Loading required package: bitops
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘bitops’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: RCurl
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘RCurl’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: stringi
#
# Loading required package: httr
#
# Loading required package: swirl
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘swirl’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Activamos los paquetes

# %%
library(devtools)
library(bitops)
library(RCurl)
library(httr)
library(swirl)
set_config( config( ssl_verifypeer = 0L ) )
# Out:
# | Hi! Type swirl() when you are ready to begin.
#
#
#
# Attaching package: ‘swirl’
#
#
# The following object is masked from ‘package:RCurl’:
#
#     reset

# %% [markdown]
# Instalamos "Programando en R"

# %%
if (file.exists("/opt/R/home/library/swirl/Courses/Programando_en_R")) {
  uninstall_course("Programando_en_R")
}
install_course_github('josersosa','Programando_en_R')
select_language(language = "spanish")
# Out:
# Downloading: 180 kB

# %% [markdown]
# También puede configurarse el lenguaje por defecto.

# %%
swirl::select_language(language = "spanish", append_rprofile = FALSE)

# %% [markdown]
# Empezamos con SWIRL

# %%
swirl()

# %% [markdown]
# ## Terminal

# %% [markdown]
# Por lo visto, Google Colab no permite hacerlo en su entorno Notebook. Por tanto, abra la **terminal**.

# %% [markdown]
# ![captura1.png](data:image/png;base64,...)

# %% [markdown]
# ![captura2.png](data:image/png;base64,...)
